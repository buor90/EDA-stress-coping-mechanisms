# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-e5055eea-6e0e-42b0-939c-8448259402f9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e5055eea-6e0e-42b0-939c-8448259402f9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # **Data Overview :**

# %%
df=pd.read_csv("Student_Mental_Stress_and_Coping_Mechanisms.csv")

# %%
df.head()
# Out:
#     Student ID  Age  Gender  Academic Performance (GPA)  Study Hours Per Week  \
# 0  802-17-3671   22  Female                           2                     9
# 1  871-12-8572   25  Female                           0                    28
# 2  495-13-2672   24  Female                           0                    45
# 3  365-77-2496   20    Male                           2                     8
# 4  664-76-5622   28    Male                           0                    14
#
#    Social Media Usage (Hours per day)  Sleep Duration (Hours per night)  \
# 0                                   2                                12
# 1                                   0                                 6
# 2                                   3                                12
# 3                                   7                                 7
# 4                                   6                                 8
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 760 entries, 0 to 759
# Data columns (total 20 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Student ID                          760 non-null    object
#  1   Age                                 760 non-null    int64
#  2   Gender                              760 non-null    object
#  3   Academic Performance (GPA)          760 non-null    int64
#  4   Study Hours Per Week                760 non-null    int64
#  5   Social Media Usage (Hours per day)  760 non-null    int64
#  6   Sleep Duration (Hours per night)    760 non-null    int64
#  7   Physical Exercise (Hours per week)  760 non-null    int64
#  8   Family Support                      760 non-null    int64
#  9   Financial Stress                    760 non-null    int64
#  10  Peer Pressure                       760 non-null    int64
# ...

# %% [markdown]
# We have 20 features and 760 observations, there's no missing data.

# %%
df.describe()
# Out:
#               Age  Academic Performance (GPA)  Study Hours Per Week  \
# count  760.000000                  760.000000            760.000000
# mean    23.919737                    1.996053             29.130263
# std      3.819392                    1.416535             18.104662
# min     18.000000                    0.000000              0.000000
# 25%     21.000000                    1.000000             13.000000
# 50%     24.000000                    2.000000             29.000000
# 75%     27.000000                    3.000000             45.000000
# max     30.000000                    4.000000             60.000000
#
#        Social Media Usage (Hours per day)  Sleep Duration (Hours per night)  \
# count                          760.000000                        760.000000
# mean                             4.234211                          8.093421
# std                              2.565174                          2.596838
# ...

# %%
df.describe(include="object")
# Out:
#          Student ID Gender Counseling Attendance Stress Coping Mechanisms  \
# count           760    760                   760                      760
# unique          760      8                     2                       10
# top     862-68-5364   Male                    No                  Reading
# freq              1    353                   387                       91
#
#        Family Mental Health History Medical Condition
# count                           760               760
# unique                            2                 2
# top                             Yes                No
# freq                            384               407

# %% [markdown]
# # **Univariate Analysis :**

# %% [markdown]
# ## **Numerical features :**

# %%
f, ax = plt.subplots(2,7, figsize=(15,5))
sns.distplot(df["Age"], ax=ax[0,0])
sns.distplot(df["Academic Performance (GPA)"], ax=ax[0,1])
sns.displot(df["Study Hours Per Week"], ax=ax[0,2])
sns.distplot(df["Social Media Usage (Hours per day)"], ax=ax[0,3])
sns.distplot(df["Sleep Duration (Hours per night)"], ax=ax[0,4])
sns.distplot(df["Physical Exercise (Hours per week)"], ax=ax[0,5])
sns.distplot(df["Family Support  "], ax=ax[0,6])
sns.distplot(df["Financial Stress"], ax=ax[1,0])
sns.distplot(df["Peer Pressure"], ax=ax[1,1])
sns.distplot(df["Relationship Stress"], ax=ax[1,2])
sns.distplot(df["Mental Stress Level"], ax=ax[1,3])
sns.distplot(df["Diet Quality"], ax=ax[1,4])
sns.distplot(df["Cognitive Distortions"], ax=ax[1,5])
sns.distplot(df["Substance Use"], ax=ax[1,6])
# Out:
# /tmp/ipython-input-440860159.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Age"], ax=ax[0,0])
# /tmp/ipython-input-440860159.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Academic Performance (GPA)"], ax=ax[0,1])
# ...

# %% [markdown]
# ##**Categorical Features :**

# %%
f, ax = plt.subplots(2,3, figsize=(18,7))
sns.countplot(x=df["Gender"], data=df,ax=ax[0,0])
sns.countplot(x=df["Counseling Attendance"], data=df, ax=ax[0,1])
sns.countplot(x=df["Stress Coping Mechanisms"], data=df, ax=ax[0,2])
sns.countplot(x=df["Family Mental Health History"], data=df, ax=ax[1,0])
sns.countplot(x=df["Medical Condition"], data=df, ax=ax[1,1])
# Out:
# <Axes: xlabel='Medical Condition', ylabel='count'>

# %% [markdown]
# # **Bivariate Analysis :**

# %% [markdown]
# Let's study how each gender cope with stress :

# %%
df['gender'] = df.loc[df["Gender"].isin(["Male", "Female"]), "Gender"]

# %%
df['gender'].value_counts()
# Out:
# gender
# Male      353
# Female    336
# Name: count, dtype: int64

# %%
ct = pd.crosstab(df["gender"], df["Stress Coping Mechanisms"])
print(ct)
# Out:
# Stress Coping Mechanisms  Exercise  Meditation  Reading  \
# gender
# Female                          26          32       34
# Male                            29          39       51
#
# Stress Coping Mechanisms  Social Media Engagement  Spending Time Alone  \
# gender
# Female                                         38                   35
# Male                                           34                   27
#
# Stress Coping Mechanisms  Talking to Friends  Travelling  \
# gender
# Female                                    29          43
# Male                                      27          33
#
# Stress Coping Mechanisms  Walking or Nature Walks  Watching Sports  Yoga
# gender
# Female                                         37               29    33
# Male                                           38               37    38

# %%
ct.plot(kind="bar", stacked=True, figsize=(8,5))
plt.title("Stress Coping Mechanisms by Gender")
plt.ylabel("Count")
plt.xlabel("Gender")
plt.legend(title="Coping Mechanism", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# So, females cope with stress with travelling and engaging in social media mainly, while males read and watch sports to cope.

# %% [markdown]
# Now we're gonna analyse the impact of the age on the financial stress.

# %%
sns.barplot(x=df["Age"], y=df["Financial Stress"])
plt.title("Financial Stress by Age")
plt.xlabel("Age")
plt.ylabel("Financial Stress")
# Out:
# Text(0, 0.5, 'Financial Stress')

# %% [markdown]
# Now we're going to study the impact of the study hours on mental stress.

# %%
sns.lineplot(x=df['Study Hours Per Week'], y=df['Mental Stress Level'])
plt.title("The impact of Study Hours on Mental Stress level")
plt.xlabel("Study Hours")
plt.ylabel("Mental Stress Level")
# Out:
# Text(0, 0.5, 'Mental Stress Level')

# %% [markdown]
# The plot shows some illogical results, cause we only got two options of how study hours would impact the stress level, students can get overwhelmed due to a lot of hours of studying so they'll get stressed, or they would get stressed for not being prepared enough and not studying enough.

# %%
correlation = df['Mental Stress Level'].corr(df['Study Hours Per Week'])
print(f"Pearson correlation coefficient (r): {correlation:.2f}")
# Out:
# Pearson correlation coefficient (r): -0.08

# %% [markdown]
# The correlation shows that those two features have nearly no linear relationship.

# %%
columns_of_interest = [
    "Age",
    "Academic Performance (GPA)",
    "Study Hours Per Week",
    "Social Media Usage (Hours per day)",
    "Sleep Duration (Hours per night)",
    "Physical Exercise (Hours per week)",
    "Family Support  ",
    "Financial Stress",
    "Peer Pressure",
    "Relationship Stress",
    "Mental Stress Level",
    "Diet Quality",
    "Cognitive Distortions",
    "Substance Use"
]



# Calculate the correlation matrix
correlation_matrix = df[columns_of_interest].corr()

# Display the correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Matrix')
plt.xticks(rotation=30, ha='right')
plt.show()
